# %%
import pandas as pd

# %%
SCOPUS_API_KEY = "" #Inserir aqui a API da Scopus
queries = [
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Upscaling\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Super-Resolution\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Deep Learning\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Upscaling\" AND \"Super-Resolution\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Upscaling\" AND \"Deep Learning\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Upscaling\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Super-Resolution\" AND \"Deep Learning\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Super-Resolution\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Deep Learning\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Upscaling\" AND \"Super-Resolution\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Upscaling\" AND \"Deep Learning\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Upscaling\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Super-Resolution\" AND \"Deep Learning\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Super-Resolution\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Deep Learning\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Upscaling\" AND \"Super-Resolution\" AND \"Deep Learning\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Upscaling\" AND \"Super-Resolution\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Upscaling\" AND \"Deep Learning\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Super-Resolution\" AND \"Deep Learning\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Upscaling\" AND \"Super-Resolution\" AND \"Deep Learning\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Upscaling\" AND \"Super-Resolution\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Upscaling\" AND \"Deep Learning\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Super-Resolution\" AND \"Deep Learning\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Upscaling\" AND \"Super-Resolution\" AND \"Deep Learning\" AND \"Texture Recreation\") AND PUBYEAR > 2018",
    "TITLE-ABS-KEY (\"Neural Networks\" AND \"Upscaling\" AND \"Super-Resolution\" AND \"Deep Learning\" AND \"Texture Recreation\") AND PUBYEAR > 2018"
]

len(queries)
# Out:
# 26

# %%
file_path = r'C:\Users\valde\Documents\TCC 2\query_0.csv'
teste = pd.read_csv(file_path, sep=',', encoding='latin1')

# %%
teste
# Out:
#              dc:creator  author-profiles:author-profile:author-profile-id  \
# 0   Koeshidayatullah A.                                               NaN
# 1               Zeng D.                                               NaN
# 2             Sharma A.                                               NaN
# 3               Chen Y.                                               NaN
# 4         Bischoff L.M.                                               NaN
# 5         Baccarelli E.                                               NaN
# 6             Sharma A.                                               NaN
# 7                Dai C.                                               NaN
# 8              Yun J.S.                                               NaN
# 9             Sahito F.                                               NaN
# 10            Sharma A.                                               NaN
# 11            Nithya B.                                               NaN
# ...

# %% [markdown]
# first = TITLE-ABS-KEY("Deep Learning" AND upscaling AND super-resolution) AND PUBYEAR > 2017 AND DOCTYPE(ar)
# doc = 56
#
# secound = TITLE-ABS-KEY ( ( "Deep Learning" OR "neural networks" ) AND ( "upscaling" OR "super-resolution" ) AND ( "texture recreation" OR "texture reconstruction" ) ) AND PUBYEAR > 2017 AND DOCTYPE ( ar )
# doc = 7
#
# thirt = TITLE-ABS-KEY ( "Deep Learning" AND upscaling AND super-resolution AND "neural networks" ) AND PUBYEAR > 2017 AND DOCTYPE ( ar )
# doc = 29
#
# four = TITLE-ABS-KEY ( "texture recreation" OR "texture reconstruction" ) AND PUBYEAR > 2020 AND DOCTYPE ( ar )
# doc = 47
#
# total 139 linhas

# %%
primeiro = pd.read_csv(r'scopus_first.csv')
segundo = pd.read_csv(r'scopus_segundo.csv')
terceiro = pd.read_csv(r'scopus_terceiro.csv')
quarto = pd.read_csv(r'scopus_quarto.csv')

# %%
resultados = pd.concat([primeiro,segundo,terceiro,quarto], ignore_index=True)

# %%
resultados.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Page count', 'Cited by', 'DOI', 'Link', 'Document Type',
#        'Publication Stage', 'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
resultados.sort_values(by='Year', inplace=True)
resultados.drop_duplicates(subset='Authors', keep='first', inplace=True)
#resultado após primeira filtragem = 104

# %%
resultados
# Out:
#                                                Authors  \
# 69                             Guei A.-C.; Akhloufi M.
# 63             Ziteng S.; Zhiren W.; Rui W.; Fuquan R.
# 25   Xu K.; Wang X.; Yang X.; He S.; Zhang Q.; Yin ...
# 42      Bellos D.; Basham M.; Pridmore T.; French A.P.
# 67               Märtens M.; Izzo D.; Krzic A.; Cox D.
# ..                                                 ...
# 104                            Chu C.; Wei Y.; Wang H.
# 90   Ju R.-Y.; Chen C.-C.; Chiang J.-S.; Lin Y.-S.;...
# 46             Zeng D.; Xu Q.; Pan S.; Song G.; Min F.
# 45   Nithya B.; Brijesh D.; Kumar S.K.; Pathmakarth...
# 136                              Shi H.; Li G.; Bao H.
#
#                                      Author full names  \
# 69   Guei, Axel-Christian (57202650067); Akhloufi, ...
# 63   Ziteng, Shi (57205130232); Zhiren, Wang (57170...
# 25   Xu, Ke (57202091928); Wang, Xin (57202370042);...
# 42   Bellos, Dimitrios (6507466198); Basham, Mark (...
# ...

# %%
import pandas as pd

data = pd.read_csv(r'complete_data.csv')
data
# Out:
#                                                  Authors  \
# 0                   Wang N.; Liao Q.; Chang H.; Zhang D.
# 1      Al-Zubaidi F.; Mostaghimi P.; Niu Y.; Armstron...
# 2                       Asiri E.C.; Chung C.Y.; Liang X.
# 3                            Sharma A.; Shrivastava B.P.
# 4                                 Sharma A.; Kannan S.R.
# ...                                                  ...
# 11437                                                NaN
# 11438  Ju R.-Y.; Chen C.-C.; Chiang J.-S.; Lin Y.-S.;...
# 11439             Jiang Z.; Zhu H.; Lu Y.; Ju G.; Men A.
# 11440                      Jain V.; Annappa B.; Dodia S.
# 11441  Greiner T.L.; Kolbjørnsen O.; Lie J.E.; Nilsen...
#
#                                        Author full names  \
# 0      Wang, Nanzhe (57215084336); Liao, Qinzhuo (560...
# 1      Al-Zubaidi, Fatimah (57557628100); Mostaghimi,...
# 2      Asiri, Elisha C. (58165870800); Chung, C.Y. (7...
# ...

# %%
len(data)
# Out:
# 11442

# %%
data['Document Type'].unique()
# Out:
# array(['Article', 'Conference paper', 'Book chapter', 'Data paper',
#        'Review', 'Note', 'Conference review', 'Erratum', 'Short survey',
#        'Letter', 'Editorial', 'Book'], dtype=object)

# %%
data = data[data['Document Type']== 'Article']
len(data)
# Out:
# 6228

# %%
data.sort_values(by=['Authors', 'Year'], ascending=[True, False], inplace=True)
data = data.drop_duplicates(subset='Authors', keep='first')
len(data)
# Out:
# 3406

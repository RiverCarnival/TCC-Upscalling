# %%
import pandas as pd

df = pd.read_csv(r'query_1.csv')

for i in range(0, 26):
    try:
        read = pd.read_csv(f'query_{i}.csv')
        tam = tam + len(read)
        df = pd.concat([df, read], axis=0, ignore_index=True)
    except:
        continue

# %%
df
# Out:
#                                                Authors  \
# 0                 Wang N.; Liao Q.; Chang H.; Zhang D.
# 1    Al-Zubaidi F.; Mostaghimi P.; Niu Y.; Armstron...
# 2                     Asiri E.C.; Chung C.Y.; Liang X.
# 3                          Sharma A.; Shrivastava B.P.
# 4                               Sharma A.; Kannan S.R.
# ..                                                 ...
# 302  Liu S.; Zhong Z.; Takbiri-Borujeni A.; Kazemi ...
# 303                     Sharma S.; Bawa V.S.; Kumar V.
# 304                     Ju C.; Su X.; Yang H.; Ning H.
# 305                           Gao X.; Zhang L.; Mou X.
# 306                            Liu P.; Hong Y.; Liu Y.
#
#                                      Author full names  \
# 0    Wang, Nanzhe (57215084336); Liao, Qinzhuo (560...
# 1    Al-Zubaidi, Fatimah (57557628100); Mostaghimi,...
# 2    Asiri, Elisha C. (58165870800); Chung, C.Y. (7...
# 3    Sharma, Ajay (57752264200); Shrivastava, Bhava...
# ...
